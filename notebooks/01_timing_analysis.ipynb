# %% [markdown]
# # Timing analysis notebook\nRun timing_experiment from rsa_lab.analysis

# %%
import sys
sys.path.insert(0, "../src")

# %%
from rsa_lab.analysis import timing_experiment
timing_experiment()
# Out:
# VULN mean 4204186.5 stdev 1161067.223793588
# CONST mean 5864032.0 stdev 363948.82356727024
# JS divergence 0.6690992911100986

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\shellbaby\Desktop\algoma\cosc5196-adv_cryptograph\project\RSACryptographyComparison\notebooks
